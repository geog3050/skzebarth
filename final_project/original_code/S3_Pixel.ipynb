# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.ma as ma
from numpy import asarray
import seaborn as sns
import rioxarray as rxr
import rasterio as rio
from rasterio.plot import plotting_extent
import geopandas as gpd
import xarray as xr
import pandas as pd
import glob
import os
import rasterstats as rs
from rasterstats import zonal_stats, point_query
from scipy.stats import linregress
from scipy.optimize import curve_fit
from scipy import stats
from sklearn.metrics import r2_score

# %%
S3_NDCI = '/mnt/nfs/lss/meerdink/data/backed_up/skzebarth/24_spring/GP_GP_Final/Sentinel-3_BSL_NDCI_RPJ.tif'
sampling_points = '/mnt/nfs/lss/meerdink/data/backed_up/skzebarth/23_BSL/9_11_23_loqate/9_11_23.shp'

# %%
NDCI = rio.open(S3_NDCI)
SP = gpd.read_file(sampling_points)
SP_transform = SP.to_crs(32615)
SP
# Out:
#     esrignss_s  esrignss_d  esrisnsr_a  esrignss_p               esrignss_r  \
# 0     1.827077  232.694063  339.387358           3  Trimble DA2, 6236100500
# 1     0.839078  235.029814   90.591900           3  Trimble DA2, 6236100500
# 2     1.022552  204.829407  181.773863           3  Trimble DA2, 6236100500
# 3     1.276173  199.202269  104.811520           3  Trimble DA2, 6236100500
# 4     1.627264  215.864834  269.460535           3  Trimble DA2, 6236100500
# 5     0.966974  228.117346  141.449898           3  Trimble DA2, 6236100500
# 6     1.518398  205.546788  182.794335           3  Trimble DA2, 6236100500
# 7     4.514390  256.188297  179.021239           3  Trimble DA2, 6236100500
# 8     1.234674  215.062654  168.101460           3  Trimble DA2, 6236100500
# 9     0.681922  220.494014  334.261545           3  Trimble DA2, 6236100500
# 10    1.958612  227.300172    4.162241           3  Trimble DA2, 6236100500
# ...

# %%
chl = SP['Value']

# %%
print(NDCI.crs)
print(SP_transform.crs)
SP_transform.plot()
# Out:
# EPSG:32615
# EPSG:32615
# <Axes: >

# %%
R_ZS = zonal_stats(SP_transform, S3_NDCI)
R_PQ = point_query(SP_transform, S3_NDCI)
R_PQ
# Out:
# /mnt/nfs/lss/meerdink/home/skzebarth/.conda/envs/geo/lib/python3.11/site-packages/rasterstats/io.py:328: NodataWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn(
# [nan,
#  0.5836979463263454,
#  nan,
#  0.1698002141738955,
#  0.5917783471587271,
#  975.411513760864,
#  0.45527204623924455,
#  0.6037822330730049,
#  0.6049143619882278,
#  0.765576755140309,
#  0.5981677412874484,
#  0.5692419610881395,
#  nan,
#  0.2883802036335056,
#  0.5804177372184978,
#  0.6211246103803515,
#  0.638124076558928,
#  0.4314427523391978,
#  0.7717040777206421,
#  0.6070438610222803,
#  0.6428480452524735,
#  0.6602306584990014,
#  0.6307299136745497,
#  0.6847154355875389,
#  0.6675757043459278,
#  nan,
#  0.4699108495616452,
#  nan,
#  0.6989675494529227,
#  0.6286604528903518,
#  0.6746335608181132,
#  0.7328376687587794,
#  0.6748084074725724,
#  0.5913507859693088,
#  nan,
#  nan,
#  1.9942905722646975,
#  nan,
#  nan,
#  nan]

# %%
mean = [point['mean'] for point in R_ZS]
mean
# Out:
# [2.354259729385376,
#  0.6741845011711121,
#  None,
#  0.3687150776386261,
#  0.5909262895584106,
#  1016.9302368164062,
#  0.45023974776268005,
#  0.5736919641494751,
#  0.6012343168258667,
#  0.8163934350013733,
#  0.6072636246681213,
#  0.5853406190872192,
#  0.5369847416877747,
#  0.47821465134620667,
#  0.5702725052833557,
#  0.5858518481254578,
#  0.6339106559753418,
#  0.7333917021751404,
#  0.7717040777206421,
#  0.5700048804283142,
#  0.5945041179656982,
#  0.6447054147720337,
#  0.6453076601028442,
#  0.7295899987220764,
#  0.7023314833641052,
#  0.8315274119377136,
#  0.6250678300857544,
#  0.2450602948665619,
#  0.7050738334655762,
#  0.6255737543106079,
#  0.6715552806854248,
#  0.763580858707428,
#  0.6646971106529236,
#  0.606001079082489,
#  0.6546489596366882,
#  0.7791810631752014,
#  0.793482780456543,
#  0.7741934657096863,
#  0.8407642245292664,
#  0.892084538936615]

# %%
x = np.array(mean)
y = np.array(chl)
df = pd.DataFrame({'x': x, 'y': y})
df_clean = df.dropna(subset=['x'])
df_final = df_clean[(df_clean['x'] <=1) & (df_clean['x'] >= -1)]
df_final
# Out:
#            x   y
# 1   0.674185  29
# 3   0.368715  25
# 4   0.590926  36
# 6    0.45024  21
# 7   0.573692  31
# 8   0.601234  22
# 9   0.816393  37
# 10  0.607264  30
# 11  0.585341  21
# 12  0.536985  23
# 13  0.478215  25
# 14  0.570273  22
# 15  0.585852  28
# 16  0.633911  27
# 17  0.733392  33
# 18  0.771704  33
# 19  0.570005  34
# 20  0.594504  35
# 21  0.644705  23
# 22  0.645308  32
# 23   0.72959  32
# 24  0.702331  44
# 25  0.831527  15
# 26  0.625068  40
# 27   0.24506  30
# 28  0.705074  28
# 29  0.625574  27
# 30  0.671555  32
# 31  0.763581  31
# 32  0.664697  26
# 33  0.606001  16
# 34  0.654649  29
# 35  0.779181  38
# 36  0.793483  19
# 37  0.774193  43
# 38  0.840764  24
# 39  0.892085  39

# %%
new_x = list(df_final['x'])
new_y = list(df_final['y'])

slope, intercept, r_value, p_value, std_err = linregress(new_x, new_y)
r_squared = r_value**2
#r_squared
r_squared
# Out:
# 0.05701217165790257

# %%
nix = np.array(new_x)
niy = np.array(new_y)
def qf(x, a, b, c):
    return a * x ** 2 + b * x + c

params, cov = curve_fit(qf, nix, niy)

pred_y = qf(nix, *params)
ss_res = np.sum((niy - pred_y) ** 2)
ss_tot = np.sum((niy - np.mean(new_y)) ** 2)
r_2 = 1 - (ss_res / ss_tot)
#r_2

p_val = [stats.t.sf(np.abs(i), len(nix) - 1) * 2 for i in params/np.sqrt(np.diag(cov))]
print('Coefficients (a, b, c):', params)
print('R-squared:', r_2)
print('P-values:', p_val)
# Out:
# Coefficients (a, b, c): [16.57194066 -7.07961956 26.55442905]
# R-squared: 0.06122063739113304
# P-values: [0.6985351037960124, 0.8921217180857186, 0.09944959503299658]

# %%
r2 = r2_score(niy, pred_y)
n = len(niy)
p = len(params) - 1
ar2 = 1 - (((1 - r2) * (n - 1)) / (n - p - 1))
ar2
# Out:
# 0.0059983219435525426

# %%
sns.regplot(x=new_x, y=new_y)
plt.xlabel('Sentinel-3 NDCI')
plt.ylabel('In-Situ Chl-a')
plt.title('RS vs IS data: S3')
plt.legend([f'p = {p_value: .3f}', f'r2 = {r_squared: .3f}'])
plt.show()
